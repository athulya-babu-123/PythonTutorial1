# %% [markdown]
# # String Operation

# %%
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")

concat = s1 + s2
print("Concatenated String:", concat)

print("Substring:", concat[1:5])
# Out:
# Enter first string:  Hello World
# Enter second string:  guyzz
# Concatenated String: Hello Worldguyzz
# Substring: ello
